# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/Temporal/blob/main/tsp_mplstyle_teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt             
# %matplotlib inline
import seaborn as sns

# %%
plt.rcParams['figure.figsize']
# Out:
# [6.0, 4.0]

# %%
url = 'https://vincentarelbundock.github.io/Rdatasets/csv/itsadug/eeg.csv'

df = pd.read_csv(url,index_col=0) # , usecols=['time','value'], index_col=['time'])
display(df.head())

fig, ax = plt.subplots()
sns.lineplot(x=df.Time, y=df.Ampl, ax=ax)
ax.set_title(url.split('/')[-1].split('.csv')[0])
plt.show()
# Out:
#   Electrode  Time      Ampl   X   Y
# 1       AF3  -190 -0.272047 -16  31
# 2       AF3  -170 -0.039482 -16  31
# 3       AF3  -150 -0.193577 -16  31
# 4       AF3  -130  0.077619 -16  31
# 5       AF3  -110  0.171835 -16  31

# %%
s = '''
figure.facecolor:   white     # figure face color
figure.edgecolor:   white     # figure edge color
figure.titlesize:   18
figure.titleweight: bold

### Axes
axes.titlesize : 16
axes.titleweight: bold
axes.labelsize : large

### Lines
lines.linewidth : 1.0
lines.markersize : 10
hatch.linewidth: 0.25
patch.antialiased   : True

### Ticks
xtick.top: True
xtick.bottom: True
xtick.major.size: 4.0
xtick.minor.size: 2.0
xtick.major.width: 0.5
xtick.minor.width: 0.5
xtick.direction: in
xtick.minor.visible: True
xtick.major.top: True
xtick.major.bottom: True
xtick.minor.top: True
xtick.minor.bottom: True
xtick.major.pad: 5.0
xtick.minor.pad: 5.0
ytick.labelsize: large
ytick.left: True
ytick.right: True
ytick.major.size: 4.0
ytick.minor.size: 2.0
ytick.major.width: 0.5
ytick.minor.width: 0.5
ytick.direction: in
ytick.minor.visible: True
ytick.major.left: True
ytick.major.right: True
ytick.minor.left: True
ytick.minor.right: True
ytick.major.pad: 5.0
ytick.minor.pad: 5.0
xtick.labelsize: large

### Legend
legend.frameon: False
legend.fontsize: 10

### Figure size
figure.figsize: 8.0, 5.0
figure.subplot.left: 0.125
figure.subplot.bottom: 0.175
figure.subplot.top: 0.95
figure.subplot.right: 0.95
figure.autolayout : False

# figure.subplot.wspace: 0.2    
# figure.subplot.hspace: 0.2

### Fonts
# font.family: serif
# font.serif: Computer Modern Roman 
# text.usetex : true

### Saving figures
path.simplify : True
'''

# %%
s.split('\n')

with open('tsp.mplstyle', 'w') as writefile:
  for line in s.split('\n'):
    writefile.write(line + '\n')

# !cat tsp.mplstyle

# %%
plt.style.use([ 'grayscale' , '/content/tsp.mplstyle' ])

url = 'https://vincentarelbundock.github.io/Rdatasets/csv/itsadug/eeg.csv'

df = pd.read_csv(url,index_col=0) # , usecols=['time','value'], index_col=['time'])
display(df.head())

fig, ax = plt.subplots()
sns.lineplot(x=df.Time, y=df.Ampl, ax=ax)
ax.set_title(url.split('/')[-1].split('.csv')[0])
plt.show()
# Out:
#   Electrode  Time      Ampl   X   Y
# 1       AF3  -190 -0.272047 -16  31
# 2       AF3  -170 -0.039482 -16  31
# 3       AF3  -150 -0.193577 -16  31
# 4       AF3  -130  0.077619 -16  31
# 5       AF3  -110  0.171835 -16  31

# %%
plt.rcParams['figure.figsize']
# Out:
# [8.0, 5.0]

# %%
plt.style.use([ 'grayscale' , '/content/tsp.mplstyle' ])

url = 'https://vincentarelbundock.github.io/Rdatasets/csv/itsadug/eeg.csv'

df = pd.read_csv(url,index_col=0) # , usecols=['time','value'], index_col=['time'])
display(df.head())

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))
sns.lineplot(x=df.Time, y=df.Ampl, ax=ax1)
ax1.set_title(url.split('/')[-1].split('.csv')[0])

sns.lineplot(x=df.Time, y=-df.Ampl, ax=ax2)
ax2.set_title('-' + url.split('/')[-1].split('.csv')[0])

plt.tight_layout()
plt.show()
# Out:
#   Electrode  Time      Ampl   X   Y
# 1       AF3  -190 -0.272047 -16  31
# 2       AF3  -170 -0.039482 -16  31
# 3       AF3  -150 -0.193577 -16  31
# 4       AF3  -130  0.077619 -16  31
# 5       AF3  -110  0.171835 -16  31

# %%
fig, ax = plt.subplots(2,2,figsize=(16,10))

for i in range(2):
  for j in range(2):
    sns.lineplot(x=df.Time, y=df.Ampl, ax=ax[i,j])
    ax[i,j].set_title(url.split('/')[-1].split('.csv')[0])

plt.tight_layout()
plt.show()
